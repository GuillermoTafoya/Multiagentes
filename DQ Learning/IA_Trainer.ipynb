# %%
# !pip install mesa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from models_DQ import *
from IA_Trafficlight import TrafficLightIA

# %%
one_hot = False
write = False
board = Board(width = 31, height = 31, spawn_rate=5, max_spawn_batch=6, one_hot = one_hot, write=write,targetSuccessfulTrips=200)

# %%
actionTranslator = list(product([True, False], repeat=4))
print(actionTranslator)
# Out:
# [(True, True, True, True), (True, True, True, False), (True, True, False, True), (True, True, False, False), (True, False, True, True), (True, False, True, False), (True, False, False, True), (True, False, False, False), (False, True, True, True), (False, True, True, False), (False, True, False, True), (False, True, False, False), (False, False, True, True), (False, False, True, False), (False, False, False, True), (False, False, False, False)]

# %%
# Check if cuda is available
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
IA = TrafficLightIA(board)

# %%
IA.train()
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Total Random Actions: 1 | Total Actions: 341
# [170] [360] Action:  10 | Reward:  0 | Was random action: False
# Successful Trips: 36 | Crashes: 0 | Stuck Time: 0
# Total Random Actions: 1 | Total Actions: 361
# [170] [380] Action:  10 | Reward:  0 | Was random action: False
# Successful Trips: 39 | Crashes: 0 | Stuck Time: 0
# Total Random Actions: 1 | Total Actions: 381
# [170] [400] Action:  10 | Reward:  0 | Was random action: False
# Successful Trips: 41 | Crashes: 0 | Stuck Time: 0
# Total Random Actions: 1 | Total Actions: 401
# [170] [420] Action:  10 | Reward:  0 | Was random action: False
# Successful Trips: 43 | Crashes: 0 | Stuck Time: 0
# Total Random Actions: 1 | Total Actions: 421
# [170] [440] Action:  10 | Reward:  0 | Was random action: False
# Successful Trips: 46 | Crashes: 0 | Stuck Time: 0
# Total Random Actions: 1 | Total Actions: 441
# ...
